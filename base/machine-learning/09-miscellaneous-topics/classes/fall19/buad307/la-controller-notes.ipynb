# %% [markdown]
# # LA Controller

# %% [markdown]
# ---
# ### Guide to Government:
#
# 1. Transparency
#
#     - Make LA most transparent on finance, operations, performance
#     - Get City to be open, accountable, accessible
#
# 2. Trust
#
#     - Ensure City Departments to do their best to serve Angelenos, and calling them out when they aren't
#
# 3. Transformation
#
#     - Using technology and innovation for a more responsive and efficient government that works with everyone
#     - Bring tech to everyone
#     - People want to use apps to interact with the people

# %% [markdown]
# ---
# ### Open Data Portal:
#
# - All Data: Data Catalog
#
#     - Central repository of data
#
#     - When it was last updated
#
#     - Number of views
#
# ---
# ### Uses of Data:
#
# - Checkbook LA
#
#     - How much the city paid for any product
#
#         - e.g. gloves, how much the city spent on gloves, mowers, mops, frozen rats, cocaine and heroine in the purest form
#
# - Balance of All City Funds
#
#     - Real time updates
#
#     - Person responsible and contact number
#
# - Mayor's Dashboard
#
#     - Turn out time
#
#     - Response time
#
#     - Call wait times
#
#     - Red means not up to expectation
#
#     - Greem means good
#
#     - Grey means passable
#
# - Audit and Reporting
#
#     - Risk Analysis using Lidar Data, Crowdsourcing to maintain an inventory of trees and their conditions to determine which trees need the most help
#
# - Annual Financial Report
#
# ---
# ### Results for Angelenos:
#
# - Collecting more than 100 million / year
#
# - Data is used to calculate which funds to collect money from
#
# - Find unutilized sources of funds
#
# - The Homelessness Crisis
#
#     - Total of 36,000 people homeless on any given night in the City
#
# - Proposition HHH
#
#     - Approved by 77% of L.A. voters in November 2016
#
#     - Funding for housing
#
#     - HHH-funded housing
#
# - Visualize Data: Mapping
#
#     - LGBTQ Resources
#
#     - LAX Noise
#
#         - Noise emissions of every plane that takes off in real time
#
#         - Age of the plane is correlated with how much noise it produces
#
#             - Trying to encourage airlines to use newer airplanes
#
#     - Parking Tickets:
#
#         - Find out where you're most likely to get tickets
#
#             - Top Ticket-getters are UPS and Fedex
# - Summer Fun in L.A.: Free City Programs
# - Property Panel
#
#     - Publicly-owned Properties in L.A. map
