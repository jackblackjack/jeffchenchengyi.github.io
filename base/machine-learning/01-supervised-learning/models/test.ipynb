# %%
import numpy as np
import random

X_test = np.load('./X_test.npy')
y_pred = np.load('./X_test_y_pred.npy')

# %%
y_pred_2 = np.load('./X_test_y_pred_2.npy')

# %%
y_pred_3 = np.load('./X_test_y_pred_3.npy')

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = (18, 12)

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = (18, 12)

fig, ax = plt.subplots(1, 1)

ax.scatter(X_test, np.sin(X_test), c='b')
ax.scatter(X_test, y_pred, c='r')
ax.scatter(X_test, y_pred_2, c='g')
ax.scatter(X_test, y_pred_3, c='black')
ax.grid()

plt.show();

# %%
fig, ax = plt.subplots(1, 1)

# ax.scatter(X_test, np.sin(X_test), c='b')
ax.scatter(X_test, y_pred, c='r')
ax.scatter(X_test, y_pred_2, c='g')
ax.scatter(X_test, y_pred_3, c='black')
ax.grid()

plt.show();
